# %% [markdown]
# ## Εργαστήριο 7
#
# Όνομα: Μάριος Παπαχρήστου
#
# ΑΜ: 03115101
#
# email : papachristoumarios@gmail.conm
#
# ### Εργοδικός Μέσος (Άσκηση 103)
#
# Στην άσκηση αυτή γίνεται προσομοίωση της αλυσίδας της  ́*Ασκησης 80* για $p = 1/2$.
# Υπενθυμίζεται ότι αυτή η αλυσίδα στον χώρο καταστάσεων $ \mathbb{N} \cup \{0\}$
# είναι μη υποβιβάσιμη, γνησίως επαναληπτική, με αναλλοίωτη κατανομή $\pi$ που δίνεται από την
#
# $$ \pi(k) = \frac{1}{2^{k+1}}, \quad k = 0, 1, 2, 3, ... $$
#
# Ο κώδικας στο παρακάτω κελί προσομοιώνει τα πρώτα $N = 10^4$ βήματα της αλυσίδας
# και επιστρέφει τον εργοδικό μέσο
#
# $$
# \frac{X_1 + X_2 + ... + X_N}{N}
# $$
#
# Από το εργοδικό Θεώρημα η παραπάνω ποσότητα συγκλίνει καθώς $N \to \infty$ με πιθανότητα 1 στο
#
# $$ \sum_{k=0}^{\infty} k \pi(k) $$
#
# οπότε ο κώδικας υπολογίζει αριθμητικά την παραπάνω ποσότητα με τη μέθοδο Markov Chain Monte
# Carlo (MCMC).

# %%
import numpy as np


def random_walk_next(state):
    if np.random.uniform() < 0.5:
        return 0
    return state + 1

def ergodic_sum(N = 10**4):
    running_state = 0
    sum_result = 0

    for i in range(N):
        running_state = random_walk_next(running_state)
        sum_result += running_state

    return sum_result / N 

    
### Ergodic Limit Theorem
Se = ergodic_sum()
print("The simulated ergodic average [X1+X2+X3+...+XN]/N is: %.4f" % Se)
# Out:
# The simulated ergodic average [X1+X2+X3+...+XN]/N is: 0.9526

# %% [markdown]
# ### Παραδοτέο 1

# %%
#1 
inf_sum  = lambda N = 1000 : sum([k / 2**(k+1) for k in range(N)])
S = inf_sum()
print('The sum using 1000 terms is {}'.format(S))
r = abs(Se - S) / S
print('Relative error is {}'.format(r))

#2
sums = np.array([ergodic_sum() for i in range(100)])
print('Variance of sums is ', np.var(sums, ddof = 1))

#3
sums = np.array([ergodic_sum(N = 2 * 10**4) for i in range(100)])
print('Variance of sums is ', np.var(sums, ddof = 1))
# Out:
# The sum using 1000 terms is 0.9999999999999999
# Relative error is 0.047399999999999894
# Variance of sums is  0.000679110580808
# Variance of sums is  0.000291085396717

# %% [markdown]
# 1. Τα αθροίσματα υπολογίζονται με τις παραπάνω ρουτίνες
# 2. Η διακύμανση των αθροισμάτων είναι 0.0006
# 3. Από τις ιδιότητες της διασποράς προκύπτει ότι $\sigma'^2 = \sigma^2 / 4$ από το οποίο λαμβάνουμε $N' = 2N$
#
# 4. Έστω $f : \mathbb N \to \mathbb [-1, 1]$ με $f(x) = 2 \cos (x + \cos x)$ και $|f(x)| \le 2$. Τότε από το εργοδικό θεώρημα ΙΙ έχουμε ότι το ζητούμενο άθροισμα δίνεται από τον εργοδικό μέσο για $N \to \infty$ $$\frac 1 N \sum_{k = 1}^N f(X_k) $$

# %%
def ergodic_sum_2(N = 10**4):
    running_state = 0
    sum_result = 0

    for i in range(N):
        running_state = random_walk_next(running_state)
        sum_result += np.cos(running_state + np.cos(running_state)) * 2 

    return sum_result / N 

S2 = ergodic_sum_2()
print('Sum of Σ cos(k + cos(k)) / 2^k) = ', S2)
# Out:
# Sum of Σ cos(k + cos(k)) / 2^k) =  0.47634478851

# %% [markdown]
# ## Παραδοτέο 2
#
# Παρατηρούμε ότι η εκτίμηση με εργοδικό μέσο δίνει μικρότερα σφάλματα.

# %%
import numpy as np
import random as r
from math import gamma, pi 

def Vol1(d):
    x = d/2
    return pi ** x / gamma(x + 1)


def mcmc_volume(dmax = 10, N = 100, delta = 1.0):
    samples = 1000 
    D = {}
    D[1] = 2 
    for d in range(1, dmax + 1):
        pts = []
        for _ in range(samples):
            x = np.zeros(d)  
            R_sq = 0.0  

            for _ in range(N):
                k = r.choice(range(d))  
                z = r.uniform(-delta,delta) 
                x_prop_k = x[k] + z   
                R_sqprop = R_sq - x[k]**2+ x_prop_k**2 
                if R_sqprop < 1.0: 
                    R_sq = R_sqprop
                    x[k]= x_prop_k   
                    pts.append(x)
                    
                    
        Npoints = len(pts)
        Nhits = 0
        # cylinder
        for p in pts:   
            xc = r.uniform(-delta, delta)
            R_sq = xc**2 + sum([g**2 for g in p])
            y = (x, )
            
            if R_sq <= 1: # p and xc are in D_{d+1}
                Nhits += 1
        ratio = Nhits / Npoints 
        # recurrence relation regarding ratii
        D[d + 1] = D[d] * ratio * 2
        
    return D

def mcmc_volume_ergodic_mean(dmax = 10, N = 100, delta = 1.0):
    D = {}
    Z = 0
    N = 100
    samples = 1000 
    D[1] = 2 
    for d in range(1, dmax+1):  
        Nhits = 0
        all = []
        R_sq = 0.0  
        x = np.zeros(d)
        l = 0 
        for _ in range(N * samples):
            k = r.choice(range(d)) if d > 1 else 0 
            z = r.uniform(-delta,delta) 
            x_prop_k = x[k] + z   
            R_sqprop = R_sq - x[k]**2+ x_prop_k**2 ## 
            if R_sqprop < 1.0: 
                    R_sq = R_sqprop
                    x[k]= x_prop_k   
            xc = r.uniform(-delta, delta)
            R_sqcl = R_sq + xc**2 
            if(R_sqcl < 1):
                Nhits += 1
        ratio = Nhits / (N * samples) 
        D[d + 1] = D[d] * ratio * 2
    return D
    


D1 = mcmc_volume(100)
D2 = mcmc_volume_ergodic_mean(100)

print('Volume computation with Ergodic Theorem\n') 
for d in D2.keys():
    Vactual = Vol1(d)
    rel = abs(Vactual - D2[d]) / Vactual
    print('MCMC Estimate for d = {} : {}, Actual = {}, (Abs) Relative Error = {}'.format(d, D2[d], Vactual,  rel))

print('Volume computation with Monte Carlo\n')
for d in D1.keys():
    Vactual = Vol1(d)
    rel = abs(Vactual - D1[d]) / Vactual 
    print('MCMC Estimate for d = {} : {}, Actual = {}, (Abs) Relative Error = {}'.format(d, D1[d], Vactual, rel))
# Out:
# Volume computation with Ergodic Theorem
#
# MCMC Estimate for d = 1 : 2, Actual = 1.9999999999999998, (Abs) Relative Error = 1.1102230246251568e-16
# MCMC Estimate for d = 2 : 3.1462, Actual = 3.141592653589793, (Abs) Relative Error = 0.0014665639114422135
# MCMC Estimate for d = 3 : 4.190864248, Actual = 4.1887902047863905, (Abs) Relative Error = 0.000495141344448119
# MCMC Estimate for d = 4 : 4.92485221239472, Actual = 4.934802200544679, (Abs) Relative Error = 0.002016289153162152
# MCMC Estimate for d = 5 : 5.286040873651749, Actual = 5.263789013914325, (Abs) Relative Error = 0.0042273464378233035
# MCMC Estimate for d = 6 : 5.149343856659115, Actual = 5.167712780049969, (Abs) Relative Error = 0.00355455579144562
# MCMC Estimate for d = 7 : 4.685799922682662, Actual = 4.7247659703314016, (Abs) Relative Error = 0.008247191055265394
# MCMC Estimate for d = 8 : 4.042814457292147, Actual = 4.058712126416768, (Abs) Relative Error = 0.003916924538980713
# MCMC Estimate for d = 9 : 3.309852196185081, Actual = 3.2985089027387064, (Abs) Relative Error = 0.00343891551632807
# MCMC Estimate for d = 10 : 2.579235422399186, Actual = 2.550164039877345, (Abs) Relative Error = 0.011399808822980338
# MCMC Estimate for d = 11 : 1.9064676548205823, Actual = 1.8841038793898994, (Abs) Relative Error = 0.011869714656032994
# MCMC Estimate for d = 12 : 1.3574812289384475, Actual = 1.3352627688545893, (Abs) Relative Error = 0.016639766046137542
# MCMC Estimate for d = 13 : 0.9247162131528704, Actual = 0.910628754783283, (Abs) Relative Error = 0.015470034627821618
# MCMC Estimate for d = 14 : 0.6063364209643372, Actual = 0.5992645293207919, (Abs) Relative Error = 0.011800951495595062
# MCMC Estimate for d = 15 : 0.38550869644912555, Actual = 0.38144328082330436, (Abs) Relative Error = 0.010657982012545683
# MCMC Estimate for d = 16 : 0.23792825727447128, Actual = 0.23533063035889312, (Abs) Relative Error = 0.011038201493858348
# MCMC Estimate for d = 17 : 0.14236199345760714, Actual = 0.14098110691713897, (Abs) Relative Error = 0.009794834007650246
# MCMC Estimate for d = 18 : 0.08183536831917089, Actual = 0.08214588661112819, (Abs) Relative Error = 0.003780083273399545
# MCMC Estimate for d = 19 : 0.04648576262002183, Actual = 0.046621601030088534, (Abs) Relative Error = 0.00291363674917631
# MCMC Estimate for d = 20 : 0.025709415874629275, Actual = 0.02580689139001405, (Abs) Relative Error = 0.0037771118540257127
# MCMC Estimate for d = 21 : 0.01381983940924822, Actual = 0.013949150409020996, (Abs) Relative Error = 0.009270170295758611
# MCMC Estimate for d = 22 : 0.007331977600182551, Actual = 0.007370430945714348, (Abs) Relative Error = 0.0052172452079150096
# MCMC Estimate for d = 23 : 0.0037554389268135025, Actual = 0.003810656386852124, (Abs) Relative Error = 0.014490275278856915
# MCMC Estimate for d = 24 : 0.0019097909118417386, Actual = 0.001929574309403922, (Abs) Relative Error = 0.01025272645151194
# MCMC Estimate for d = 25 : 0.0009590969959269211, Actual = 0.0009577224088231723, (Abs) Relative Error = 0.0014352667235152982
# MCMC Estimate for d = 26 : 0.00046460576676691915, Actual = 0.00046630280576761234, (Abs) Relative Error = 0.0036393497523558235
# MCMC Estimate for d = 27 : 0.00022176562459318586, Actual = 0.000222872124721274, (Abs) Relative Error = 0.0049647309167619134
# MCMC Estimate for d = 28 : 0.00010391050105938317, Actual = 0.00010463810492484565, (Abs) Relative Error = 0.006953526786299048
# MCMC Estimate for d = 29 : 4.80108079094774e-05, Actual = 4.8287822738917413e-05, (Abs) Relative Error = 0.0057367430073991576
# MCMC Estimate for d = 30 : 2.192077467530919e-05, Actual = 2.1915353447830204e-05, (Abs) Relative Error = 0.00024737120904269827
# MCMC Estimate for d = 31 : 9.727124554421702e-06, Actual = 9.787139946737361e-06, (Abs) Relative Error = 0.006132066430261525
# MCMC Estimate for d = 32 : 4.308727092626637e-06, Actual = 4.303069587032944e-06, (Abs) Relative Error = 0.0013147604237546398
# MCMC Estimate for d = 33 : 1.8693843364069927e-06, Actual = 1.863467088262139e-06, (Abs) Relative Error = 0.0031753971841660816
# MCMC Estimate for d = 34 : 7.98002785525417e-07, Actual = 7.952054001475508e-07, (Abs) Relative Error = 0.0035178148656273556
# MCMC Estimate for d = 35 : 3.3532077047778026e-07, Actual = 3.345288294108971e-07, (Abs) Relative Error = 0.0023673327894571873
# MCMC Estimate for d = 36 : 1.4040551301445615e-07, Actual = 1.387895246221376e-07, (Abs) Relative Error = 0.011643446410802009
# MCMC Estimate for d = 37 : 5.812788238798484e-08, Actual = 5.6808287183311744e-08, (Abs) Relative Error = 0.023228920815988777
# MCMC Estimate for d = 38 : 2.3620846287181522e-08, Actual = 2.2948428997269856e-08, (Abs) Relative Error = 0.02930123408411365
# MCMC Estimate for d = 39 : 9.367082803644705e-09, Actual = 9.152230650159558e-09, (Abs) Relative Error = 0.02347538667870021
# MCMC Estimate for d = 40 : 3.6634660845054442e-09, Actual = 3.6047307974624982e-09, (Abs) Relative Error = 0.016293945468630253
# MCMC Estimate for d = 41 : 1.4374708222382462e-09, Actual = 1.4025649060732007e-09, (Abs) Relative Error = 0.024887202021026334
# MCMC Estimate for d = 42 : 5.581411708586662e-10, Actual = 5.392664662608125e-10, (Abs) Relative Error = 0.035000701469030615
# MCMC Estimate for d = 43 : 2.1121178187633647e-10, Actual = 2.0494360953964767e-10, (Abs) Relative Error = 0.030584863566951958
# MCMC Estimate for d = 44 : 8.119825742453879e-11, Actual = 7.700707130601346e-11, (Abs) Relative Error = 0.05442599033367003
# MCMC Estimate for d = 45 : 3.061823890964509e-11, Actual = 2.86155261391081e-11, (Abs) Relative Error = 0.06998692810333941
# MCMC Estimate for d = 46 : 1.1164634636012985e-11, Actual = 1.0518471716932059e-11, (Abs) Relative Error = 0.061431255078698246
# MCMC Estimate for d = 47 : 4.005647614708739e-12, Actual = 3.825460710520369e-12, (Abs) Relative Error = 0.04710201406404191
# MCMC Estimate for d = 48 : 1.4581358447062752e-12, Actual = 1.3768647280377408e-12, (Abs) Relative Error = 0.05902621732808798
# MCMC Estimate for d = 49 : 5.120098205101615e-13, Actual = 4.905322148884564e-13, (Abs) Relative Error = 0.04378429177498351
# MCMC Estimate for d = 50 : 1.8156892254931347e-13, Actual = 1.7302192458361097e-13, (Abs) Relative Error = 0.049398352181502014
# MCMC Estimate for d = 51 : 6.355638564916169e-14, Actual = 6.043342755461588e-14, (Abs) Relative Error = 0.051676004835626496
# MCMC Estimate for d = 52 : 2.154942811820476e-14, Actual = 2.0906323353147666e-14, (Abs) Relative Error = 0.03076125601780038
# MCMC Estimate for d = 53 : 7.483254408327785e-15, Actual = 7.164423095729517e-15, (Abs) Relative Error = 0.044502021773157506
# MCMC Estimate for d = 54 : 2.5288909947502918e-15, Actual = 2.4325611799933862e-15, (Abs) Relative Error = 0.03960016115901656
# MCMC Estimate for d = 55 : 8.533995550884334e-16, Actual = 8.184617805364689e-16, (Abs) Relative Error = 0.04268711793611695
# MCMC Estimate for d = 56 : 2.8334572028046164e-16, Actual = 2.7293272615981923e-16, (Abs) Relative Error = 0.03815223724598328
# MCMC Estimate for d = 57 : 9.368542895353183e-17, Actual = 9.022012340271548e-17, (Abs) Relative Error = 0.03840945257133234
# MCMC Estimate for d = 58 : 3.0419658781211784e-17, Actual = 2.956701542854907e-17, (Abs) Relative Error = 0.028837653726775086
# MCMC Estimate for d = 59 : 9.937494130646266e-18, Actual = 9.607961928404593e-18, (Abs) Relative Error = 0.03429782556355241
# MCMC Estimate for d = 60 : 3.206233106311711e-18, Actual = 3.096250615296861e-18, (Abs) Relative Error = 0.03552118503311316
# MCMC Estimate for d = 61 : 1.0300985723958266e-18, Actual = 9.896492659097147e-19, (Abs) Relative Error = 0.040872365472761366
# MCMC Estimate for d = 62 : 3.225650669600291e-19, Actual = 3.137792963448224e-19, (Abs) Relative Error = 0.027999841664351738
# MCMC Estimate for d = 63 : 1.0109189198527313e-19, Actual = 9.870078931468227e-20, (Abs) Relative Error = 0.024225770504908983
# MCMC Estimate for d = 64 : 3.135263938031261e-20, Actual = 3.080521038267089e-20, (Abs) Relative Error = 0.017770662522391636
# MCMC Estimate for d = 65 : 9.707404204932392e-21, Actual = 9.54085152660061e-21, (Abs) Relative Error = 0.01745679385822328
# MCMC Estimate for d = 66 : 3.030457444695794e-21, Actual = 2.9326491706208156e-21, (Abs) Relative Error = 0.03335150861371987
# MCMC Estimate for d = 67 : 9.385932797711814e-22, Actual = 8.947304198495348e-22, (Abs) Relative Error = 0.049023548264987886
# MCMC Estimate for d = 68 : 2.847316573513856e-22, Actual = 2.709761497052516e-22, (Abs) Relative Error = 0.050762798353641926
# MCMC Estimate for d = 69 : 8.662675943258555e-23, Actual = 8.147473953456843e-23, (Abs) Relative Error = 0.06323456727138364
# MCMC Estimate for d = 70 : 2.5518510793651052e-23, Actual = 2.4322762320344753e-23, (Abs) Relative Error = 0.04916170530129779
# MCMC Estimate for d = 71 : 7.611661399530235e-24, Actual = 7.210153328871608e-24, (Abs) Relative Error = 0.055686481596843265
# MCMC Estimate for d = 72 : 2.2605112024324893e-24, Actual = 2.1225614283501585e-24, (Abs) Relative Error = 0.06499212330903303
# MCMC Estimate for d = 73 : 6.528356352625029e-25, Actual = 6.205853350476447e-25, (Abs) Relative Error = 0.05196755126735675
# MCMC Estimate for d = 74 : 1.8673710511048634e-25, Actual = 1.8022225378643015e-25, (Abs) Relative Error = 0.036148983753008256
# MCMC Estimate for d = 75 : 5.373920410869576e-26, Actual = 5.199003545363311e-26, (Abs) Relative Error = 0.03364430587131703
# MCMC Estimate for d = 76 : 1.4978190969175683e-26, Actual = 1.4899602855495902e-26, (Abs) Relative Error = 0.005274510632395324
# MCMC Estimate for d = 77 : 4.168730110540977e-27, Actual = 4.2423769724936784e-27, (Abs) Relative Error = 0.017359810886728416
# MCMC Estimate for d = 78 : 1.1860037164489078e-27, Actual = 1.2002175095443955e-27, (Abs) Relative Error = 0.011842680999449202
# MCMC Estimate for d = 79 : 3.3459536848456587e-28, Actual = 3.374131729251809e-28, (Abs) Relative Error = 0.008351198668938345
# MCMC Estimate for d = 80 : 9.397445519257517e-29, Actual = 9.426486276736277e-29, (Abs) Relative Error = 0.0030807616566981074
# MCMC Estimate for d = 81 : 2.626773971542861e-29, Actual = 2.617320358731286e-29, (Abs) Relative Error = 0.003611943329764026
# MCMC Estimate for d = 82 : 7.282468158705428e-30, Actual = 7.222970740526754e-30, (Abs) Relative Error = 0.008237250338679196
# MCMC Estimate for d = 83 : 1.98592906687897e-30, Actual = 1.9813384123087263e-30, (Abs) Relative Error = 0.002316946232771302
# MCMC Estimate for d = 84 : 5.401727061910799e-31, Actual = 5.402769479888779e-31, (Abs) Relative Error = 0.00019294141307722284
# MCMC Estimate for d = 85 : 1.4722947279944075e-31, Actual = 1.4646019295022018e-31, (Abs) Relative Error = 0.005252484198775019
# MCMC Estimate for d = 86 : 4.070600463958938e-32, Actual = 3.9472792807111023e-32, (Abs) Relative Error = 0.031242071938122215
# MCMC Estimate for d = 87 : 1.0980851811575631e-32, Actual = 1.0577431407258743e-32, (Abs) Relative Error = 0.038139732491202075
# MCMC Estimate for d = 88 : 2.9589003291471693e-33, Actual = 2.8183508158975456e-33, (Abs) Relative Error = 0.04986941741135361
# MCMC Estimate for d = 89 : 8.026313032844612e-34, Actual = 7.467411416380678e-34, (Abs) Relative Error = 0.07484542973458178
# MCMC Estimate for d = 90 : 2.1187861144103204e-34, Actual = 1.9675800485472293e-34, (Abs) Relative Error = 0.07684874929217474
# MCMC Estimate for d = 91 : 5.53299805917111e-35, Actual = 5.155948318029469e-35, (Abs) Relative Error = 0.07312907691940251
# MCMC Estimate for d = 92 : 1.4672404253309952e-35, Actual = 1.3437684838838745e-35, (Abs) Relative Error = 0.09188483204357605
# MCMC Estimate for d = 93 : 3.8315516467093604e-36, Actual = 3.483417066281728e-36, (Abs) Relative Error = 0.09994053936218386
# MCMC Estimate for d = 94 : 9.692293045515999e-37, Actual = 8.98207063211718e-37, (Abs) Relative Error = 0.07907112318392126
# MCMC Estimate for d = 95 : 2.5147623535895815e-37, Actual = 2.3038899925936815e-37, (Abs) Relative Error = 0.09152883239815776
# MCMC Estimate for d = 96 : 6.465454011078813e-38, Actual = 5.878751481642491e-38, (Abs) Relative Error = 0.0998005326927685
# MCMC Estimate for d = 97 : 1.6215358659785665e-38, Actual = 1.492347190806464e-38, (Abs) Relative Error = 0.0865674395127108
# MCMC Estimate for d = 98 : 4.083675924880422e-39, Actual = 3.769110707552687e-39, (Abs) Relative Error = 0.08345873648587641
# MCMC Estimate for d = 99 : 1.0186321227021725e-39, Actual = 9.471408022713036e-40, (Abs) Relative Error = 0.07548119588917317
# MCMC Estimate for d = 100 : 2.5530995523407246e-40, Actual = 2.3682021018828293e-40, (Abs) Relative Error = 0.07807503012977372
# MCMC Estimate for d = 101 : 6.456278147959224e-41, Actual = 5.892139774912219e-41, (Abs) Relative Error = 0.09574422783536396
# Volume computation with Monte Carlo
#
# MCMC Estimate for d = 1 : 2, Actual = 1.9999999999999998, (Abs) Relative Error = 1.1102230246251568e-16
# MCMC Estimate for d = 2 : 3.1638047360762007, Actual = 3.141592653589793, (Abs) Relative Error = 0.007070325448153374
# MCMC Estimate for d = 3 : 4.234015560570861, Actual = 4.1887902047863905, (Abs) Relative Error = 0.010796758389282214
# MCMC Estimate for d = 4 : 5.065664415492575, Actual = 4.934802200544679, (Abs) Relative Error = 0.026518229025157783
# MCMC Estimate for d = 5 : 5.476257718173023, Actual = 5.263789013914325, (Abs) Relative Error = 0.04036421362958453
# MCMC Estimate for d = 6 : 5.286846400465784, Actual = 5.167712780049969, (Abs) Relative Error = 0.023053452365954144
# MCMC Estimate for d = 7 : 4.8003508142722096, Actual = 4.7247659703314016, (Abs) Relative Error = 0.015997584730213923
# MCMC Estimate for d = 8 : 4.1116056378696655, Actual = 4.058712126416768, (Abs) Relative Error = 0.013032092399121419
# MCMC Estimate for d = 9 : 3.356382305684837, Actual = 3.2985089027387064, (Abs) Relative Error = 0.017545322645053055
# MCMC Estimate for d = 10 : 2.5299830071115514, Actual = 2.550164039877345, (Abs) Relative Error = 0.007913621418159548
# MCMC Estimate for d = 11 : 1.9431075846051242, Actual = 1.8841038793898994, (Abs) Relative Error = 0.03131658814604801
# MCMC Estimate for d = 12 : 1.4180363775505551, Actual = 1.3352627688545893, (Abs) Relative Error = 0.06199050151527135
# MCMC Estimate for d = 13 : 0.983006838390714, Actual = 0.910628754783283, (Abs) Relative Error = 0.07948143876112941
# MCMC Estimate for d = 14 : 0.6729754490716899, Actual = 0.5992645293207919, (Abs) Relative Error = 0.1230023072355746
# MCMC Estimate for d = 15 : 0.4307919495385261, Actual = 0.38144328082330436, (Abs) Relative Error = 0.12937354305654028
# MCMC Estimate for d = 16 : 0.2683252553111307, Actual = 0.23533063035889312, (Abs) Relative Error = 0.1402053991098347
# MCMC Estimate for d = 17 : 0.1648347633674984, Actual = 0.14098110691713897, (Abs) Relative Error = 0.16919753981204944
# MCMC Estimate for d = 18 : 0.09632312048151026, Actual = 0.08214588661112819, (Abs) Relative Error = 0.17258604727825166
# MCMC Estimate for d = 19 : 0.0553232459197511, Actual = 0.046621601030088534, (Abs) Relative Error = 0.18664405977921525
# MCMC Estimate for d = 20 : 0.03044303997264242, Actual = 0.02580689139001405, (Abs) Relative Error = 0.17964769613523934
# MCMC Estimate for d = 21 : 0.016427600404979478, Actual = 0.013949150409020996, (Abs) Relative Error = 0.17767748739418948
# MCMC Estimate for d = 22 : 0.008777116482085984, Actual = 0.007370430945714348, (Abs) Relative Error = 0.19085526297340527
# MCMC Estimate for d = 23 : 0.004509359073958436, Actual = 0.003810656386852124, (Abs) Relative Error = 0.1833549436566991
# MCMC Estimate for d = 24 : 0.0022869872706437694, Actual = 0.001929574309403922, (Abs) Relative Error = 0.1852289178488587
# MCMC Estimate for d = 25 : 0.001113182752395791, Actual = 0.0009577224088231723, (Abs) Relative Error = 0.16232296763698453
# MCMC Estimate for d = 26 : 0.0005241208549925132, Actual = 0.00046630280576761234, (Abs) Relative Error = 0.12399249695639872
# MCMC Estimate for d = 27 : 0.00024667595943777057, Actual = 0.000222872124721274, (Abs) Relative Error = 0.10680489875647699
# MCMC Estimate for d = 28 : 0.0001208646962716752, Actual = 0.00010463810492484565, (Abs) Relative Error = 0.15507344440616538
# MCMC Estimate for d = 29 : 5.6968020989161724e-05, Actual = 4.8287822738917413e-05, (Abs) Relative Error = 0.17975956996811399
# MCMC Estimate for d = 30 : 2.544640072196504e-05, Actual = 2.1915353447830204e-05, (Abs) Relative Error = 0.1611220773847222
# MCMC Estimate for d = 31 : 1.1315259544984e-05, Actual = 9.787139946737361e-06, (Abs) Relative Error = 0.15613546005910048
# MCMC Estimate for d = 32 : 4.955253380087916e-06, Actual = 4.303069587032944e-06, (Abs) Relative Error = 0.15156245555969877
# MCMC Estimate for d = 33 : 2.100041028589729e-06, Actual = 1.863467088262139e-06, (Abs) Relative Error = 0.12695364560917344
# MCMC Estimate for d = 34 : 9.063433439150712e-07, Actual = 7.952054001475508e-07, (Abs) Relative Error = 0.1397600465828057
# MCMC Estimate for d = 35 : 3.810126835908978e-07, Actual = 3.345288294108971e-07, (Abs) Relative Error = 0.13895320849284773
# MCMC Estimate for d = 36 : 1.5673290163327348e-07, Actual = 1.387895246221376e-07, (Abs) Relative Error = 0.12928480776908588
# MCMC Estimate for d = 37 : 6.60213131875216e-08, Actual = 5.6808287183311744e-08, (Abs) Relative Error = 0.16217750016790353
# MCMC Estimate for d = 38 : 2.606044729144119e-08, Actual = 2.2948428997269856e-08, (Abs) Relative Error = 0.1356092085668072
# MCMC Estimate for d = 39 : 9.800716499426125e-09, Actual = 9.152230650159558e-09, (Abs) Relative Error = 0.07085549676955115
# MCMC Estimate for d = 40 : 3.961214842234871e-09, Actual = 3.6047307974624982e-09, (Abs) Relative Error = 0.09889338893858997
# MCMC Estimate for d = 41 : 1.5002511796204138e-09, Actual = 1.4025649060732007e-09, (Abs) Relative Error = 0.06964830869803242
# MCMC Estimate for d = 42 : 5.763045156758072e-10, Actual = 5.392664662608125e-10, (Abs) Relative Error = 0.06868227811718135
# MCMC Estimate for d = 43 : 2.1980508118875255e-10, Actual = 2.0494360953964767e-10, (Abs) Relative Error = 0.07251493072893218
# MCMC Estimate for d = 44 : 8.353792715980375e-11, Actual = 7.700707130601346e-11, (Abs) Relative Error = 0.08480852138679236
# MCMC Estimate for d = 45 : 3.1364567675749913e-11, Actual = 2.86155261391081e-11, (Abs) Relative Error = 0.09606818072391718
# MCMC Estimate for d = 46 : 1.1037115115823122e-11, Actual = 1.0518471716932059e-11, (Abs) Relative Error = 0.04930786647039033
# MCMC Estimate for d = 47 : 4.138860862540027e-12, Actual = 3.825460710520369e-12, (Abs) Relative Error = 0.08192481265270327
# MCMC Estimate for d = 48 : 1.4287603437135494e-12, Actual = 1.3768647280377408e-12, (Abs) Relative Error = 0.03769115049505874
# MCMC Estimate for d = 49 : 5.155093657251098e-13, Actual = 4.905322148884564e-13, (Abs) Relative Error = 0.05091847197504238
# MCMC Estimate for d = 50 : 1.7974112336549252e-13, Actual = 1.7302192458361097e-13, (Abs) Relative Error = 0.038834377770630826
# MCMC Estimate for d = 51 : 6.412996408895763e-14, Actual = 6.043342755461588e-14, (Abs) Relative Error = 0.06116708391231096
# MCMC Estimate for d = 52 : 2.2696428369649593e-14, Actual = 2.0906323353147666e-14, (Abs) Relative Error = 0.0856250516297696
# MCMC Estimate for d = 53 : 7.224474578878679e-15, Actual = 7.164423095729517e-15, (Abs) Relative Error = 0.008381900726236602
# MCMC Estimate for d = 54 : 2.348950772369029e-15, Actual = 2.4325611799933862e-15, (Abs) Relative Error = 0.034371348318805554
# MCMC Estimate for d = 55 : 7.910329216673203e-16, Actual = 8.184617805364689e-16, (Abs) Relative Error = 0.03351269359354824
# MCMC Estimate for d = 56 : 2.4991921124384276e-16, Actual = 2.7293272615981923e-16, (Abs) Relative Error = 0.08431936777893248
# MCMC Estimate for d = 57 : 7.8956260852562e-17, Actual = 9.022012340271548e-17, (Abs) Relative Error = 0.12484867150840598
# MCMC Estimate for d = 58 : 2.5841522674534805e-17, Actual = 2.956701542854907e-17, (Abs) Relative Error = 0.12600165082665174
# MCMC Estimate for d = 59 : 8.26083408845967e-18, Actual = 9.607961928404593e-18, (Abs) Relative Error = 0.140209531426465
# MCMC Estimate for d = 60 : 2.5620450426955256e-18, Actual = 3.096250615296861e-18, (Abs) Relative Error = 0.17253305335237437
# MCMC Estimate for d = 61 : 7.87937824544162e-19, Actual = 9.896492659097147e-19, (Abs) Relative Error = 0.2038211397854508
# MCMC Estimate for d = 62 : 2.463524039021984e-19, Actual = 3.137792963448224e-19, (Abs) Relative Error = 0.21488636512374085
# MCMC Estimate for d = 63 : 7.434151626601201e-20, Actual = 9.870078931468227e-20, (Abs) Relative Error = 0.2467991716966613
# MCMC Estimate for d = 64 : 2.3134124537108954e-20, Actual = 3.080521038267089e-20, (Abs) Relative Error = 0.24901910262158825
# MCMC Estimate for d = 65 : 7.1212754133867e-21, Actual = 9.54085152660061e-21, (Abs) Relative Error = 0.25360169440515345
# MCMC Estimate for d = 66 : 2.1820535114652837e-21, Actual = 2.9326491706208156e-21, (Abs) Relative Error = 0.2559445796227435
# MCMC Estimate for d = 67 : 6.385108975016109e-22, Actual = 8.947304198495348e-22, (Abs) Relative Error = 0.2863650510407502
# MCMC Estimate for d = 68 : 1.8178581386312273e-22, Actual = 2.709761497052516e-22, (Abs) Relative Error = 0.32914459792547696
# MCMC Estimate for d = 69 : 5.168815825120737e-23, Actual = 8.147473953456843e-23, (Abs) Relative Error = 0.3655928383879409
# MCMC Estimate for d = 70 : 1.5574172379869357e-23, Actual = 2.4322762320344753e-23, (Abs) Relative Error = 0.35968735069033037
# MCMC Estimate for d = 71 : 4.4398117772939035e-24, Actual = 7.210153328871608e-24, (Abs) Relative Error = 0.38422782778896386
# MCMC Estimate for d = 72 : 1.2259757083106547e-24, Actual = 2.1225614283501585e-24, (Abs) Relative Error = 0.42240743097664274
# MCMC Estimate for d = 73 : 3.5480308517843863e-25, Actual = 6.205853350476447e-25, (Abs) Relative Error = 0.42827671693015584
# MCMC Estimate for d = 74 : 9.859340893084538e-26, Actual = 1.8022225378643015e-25, (Abs) Relative Error = 0.45293432492703084
# MCMC Estimate for d = 75 : 3.0094438993274583e-26, Actual = 5.199003545363311e-26, (Abs) Relative Error = 0.421149865917786
# MCMC Estimate for d = 76 : 8.263391439335647e-27, Actual = 1.4899602855495902e-26, (Abs) Relative Error = 0.44539518808129885
# MCMC Estimate for d = 77 : 2.154595246928696e-27, Actual = 4.2423769724936784e-27, (Abs) Relative Error = 0.49212546152818193
# MCMC Estimate for d = 78 : 5.838144166497362e-28, Actual = 1.2002175095443955e-27, (Abs) Relative Error = 0.5135761543161013
# MCMC Estimate for d = 79 : 1.5711268737440073e-28, Actual = 3.374131729251809e-28, (Abs) Relative Error = 0.5343611335256332
# MCMC Estimate for d = 80 : 4.345568398634951e-29, Actual = 9.426486276736277e-29, (Abs) Relative Error = 0.5390044316555762
# MCMC Estimate for d = 81 : 1.1232892815300833e-29, Actual = 2.617320358731286e-29, (Abs) Relative Error = 0.570824688012367
# MCMC Estimate for d = 82 : 3.0606510403947608e-30, Actual = 7.222970740526754e-30, (Abs) Relative Error = 0.5762614649368558
# MCMC Estimate for d = 83 : 8.053327987403784e-31, Actual = 1.9813384123087263e-30, (Abs) Relative Error = 0.5935410156400411
# MCMC Estimate for d = 84 : 2.0467850519256992e-31, Actual = 5.402769479888779e-31, (Abs) Relative Error = 0.6211600255119835
# MCMC Estimate for d = 85 : 5.598373573568908e-32, Actual = 1.4646019295022018e-31, (Abs) Relative Error = 0.6177545952386039
# MCMC Estimate for d = 86 : 1.5266956526630914e-32, Actual = 3.9472792807111023e-32, (Abs) Relative Error = 0.6132283671633041
# MCMC Estimate for d = 87 : 3.829868956667401e-33, Actual = 1.0577431407258743e-32, (Abs) Relative Error = 0.637920700290322
# MCMC Estimate for d = 88 : 9.905154520889923e-34, Actual = 2.8183508158975456e-33, (Abs) Relative Error = 0.6485478505721268
# MCMC Estimate for d = 89 : 2.507140750861318e-34, Actual = 7.467411416380678e-34, (Abs) Relative Error = 0.6642557090986578
# MCMC Estimate for d = 90 : 6.359805587972004e-35, Actual = 1.9675800485472293e-34, (Abs) Relative Error = 0.67677017295089
# MCMC Estimate for d = 91 : 1.657420114797379e-35, Actual = 5.155948318029469e-35, (Abs) Relative Error = 0.6785421395707819
# MCMC Estimate for d = 92 : 4.2768668477280675e-36, Actual = 1.3437684838838745e-35, (Abs) Relative Error = 0.6817259149160352
# MCMC Estimate for d = 93 : 1.0517110771620224e-36, Actual = 3.483417066281728e-36, (Abs) Relative Error = 0.6980806325655857
# MCMC Estimate for d = 94 : 2.6149788148709845e-37, Actual = 8.98207063211718e-37, (Abs) Relative Error = 0.7088668167982772
# MCMC Estimate for d = 95 : 6.388572738565022e-38, Actual = 2.3038899925936815e-37, (Abs) Relative Error = 0.7227049573068863
# MCMC Estimate for d = 96 : 1.606273692311933e-38, Actual = 5.878751481642491e-38, (Abs) Relative Error = 0.7267661854174606
# MCMC Estimate for d = 97 : 3.673989199018228e-39, Actual = 1.492347190806464e-38, (Abs) Relative Error = 0.7538113636255914
# MCMC Estimate for d = 98 : 8.257399941521457e-40, Actual = 3.769110707552687e-39, (Abs) Relative Error = 0.7809191455964676
# MCMC Estimate for d = 99 : 1.859728962035168e-40, Actual = 9.471408022713036e-40, (Abs) Relative Error = 0.8036480998838378
# MCMC Estimate for d = 100 : 4.4051959308734397e-41, Actual = 2.3682021018828293e-40, (Abs) Relative Error = 0.8139856422147794
# MCMC Estimate for d = 101 : 1.0352198189329454e-41, Actual = 5.892139774912219e-41, (Abs) Relative Error = 0.8243049454901351
